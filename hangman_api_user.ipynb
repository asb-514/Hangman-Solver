# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []

        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)
        self.ndupdict = []
        for word in self.full_dictionary:
            temp = ""
            for i in range(len(word)):
                if word[i] not in temp:
                    temp += word[i]
            self.ndupdict.append(temp)
        self.full_dictionary_common_letter_sorted = collections.Counter(
            "".join(self.ndupdict)
        ).most_common()

        self.current_dictionary = []
        self.start = 1

    @staticmethod
    def determine_hangman_url():
        links = ["https://trexsim.com", "https://sg.trexsim.com"]

        data = {link: 0 for link in links}

        for link in links:
            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += "/trexsim/hangman"
        return link

    def guess(self, word):  # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        clean_word = word[::2].replace("_", ".")
        clean_word = "^" + clean_word
        clean_word = clean_word + "$"

        # find length of passed word
        len_word = len(clean_word)
        short_dash = len_word
        cnt = 0
        for i in range(len_word - 1):
            if clean_word[i] != ".":
                continue
            cnt += 1
            if clean_word[i] == clean_word[i + 1]:
                continue
            short_dash = min(short_dash, cnt)
            cnt = 0
        if cnt != 0:
            short_dash = min(short_dash, cnt)
            cnt = 0
        if self.start == 1:
            new_dictionary = []
            for word in self.current_dictionary:
                word = "^" + word
                word = word + "$"
                new_dictionary.append(word)
            self.current_dictionary = new_dictionary

        new_dictionary = self.current_dictionary

        # returns how many characters are common in string a and b
        def _score(a, b):
            return sum([a[i] == b[i] for i in range(min(len(a), len(b)))])
        # returns the offset for best match between string a and b
        def best_match(a, b):
            maxi = 0
            _max_score = 0
            for offset in range(len(a)):
                val = pow(7, _score(a[offset:], b)) / (offset + 1)
                if val > _max_score:
                    _max_score = val
                    maxi = offset
            return maxi

        score = {}
        max_once = 0
        max_word = ""
        for dict_word in new_dictionary:
            shift = best_match(clean_word, dict_word)
            # print(dict_word,shift,clean_word)
            cnt = 0
            penalty = shift
            while shift > 0:
                cnt += 1
                dict_word = "!" + dict_word
                shift -= 1
            if cnt == 0:
                shift = best_match(dict_word, clean_word)
                penalty = shift
                while shift > 0:
                    dict_word = dict_word + "!"
                    shift -= 1
            sync = _score(dict_word, clean_word)

            for i in range(min(len_word, len(dict_word))):
                scorenow = 0
                if clean_word[i] != ".":
                    continue
                if dict_word[i] == "!" or dict_word[i] == "^" or dict_word[i] == "$":
                    continue
                if dict_word[i] in self.guessed_letters:
                    continue
                start = 4.5
                prev = start
                inc = pow((short_dash) / (len_word), 1.1)
                if sync < 2:
                    continue
                for j in range(i + 1, min(len_word, len(dict_word))):
                    if dict_word[j] == "!":
                        break
                        # adding probabilistic chance if the word is not revealed at
                    elif (
                        clean_word[j] == "."
                        and dict_word[j] not in self.guessed_letters
                    ):
                        scorenow = scorenow + pow(prev, 1) / (
                            26 - len(self.guessed_letters)
                        )
                    elif clean_word[j] == dict_word[j]:
                        scorenow = scorenow + pow(prev, 1)
                    prev *= inc
                prev = start
                for j in reversed(range(0, i)):
                    if dict_word[j] == "!":
                        break
                    elif (
                        clean_word[j] == "."
                        and dict_word[j] not in self.guessed_letters
                    ):
                        scorenow = scorenow + pow(prev, 1) / (
                            26 - len(self.guessed_letters)
                        )
                    elif clean_word[j] == dict_word[j]:
                        scorenow = scorenow + pow(prev, 1)
                    prev *= inc
                if dict_word[i] not in score.keys():
                    score.update({dict_word[i]: 0})

                # print(i,scorenow)
                penalty = max(1, penalty)
                sync = max(1, sync)
                score[dict_word[i]] += (
                    (scorenow / pow(penalty, 1)) * pow(7, sync)
                ) * pow(i + 1, 0.65)
                if max_once < (
                    (scorenow / pow(penalty, 1)) * pow(7 ,sync) * pow(i + 1, 0.65)
                ):
                    max_once = max(
                        max_once,
                        ((scorenow / pow(penalty, 1)) * pow(7 ,sync) * pow(i + 1, 0.65)),
                    )
                    max_word = dict_word[i] + "  " + dict_word
        # count occurrence of all characters in possible word matches
        
        #some variables are used for debugging or for the perpose of analysing the algrithm, please ignore them.
        max_score = 0
        max_score_char = "!"
        smax_score_char = "!"
        total = 1
        for ele in score:
            total += score[ele]
            if max_score < score[ele]:
                if ele not in self.guessed_letters:
                    max_score = score[ele]
                    smax_score_char = max_score_char
                    max_score_char = ele
        # print(score)
        # print("certainity :", end=" ")
        # print(max_score / total)
        # print("second best char :", end="  ")
        # print(smax_score_char)
        # print("max score at once is:", end="  ")
        # print(max_once, end="  ")
        # print(max_word)
        guess_letter = max_score_char
        # if no word matches in training dictionary, default back to ordering of full dictionary
        # print(max_score)
        cnt = 0
        for cha in clean_word:
            if cha != ".":
                cnt += 1
                
                
        #until 20 percent of word is not guessed, use the frequency aproach itself
        if guess_letter == "!" or cnt <= (0.2 * (len_word - 2) + 2) and len_word >= 8:
            # print("couldnt guess")
            # self.current_dictionary = self.full_dictionary
            newndup = []
            for word in self.ndupdict:
                flag = 0
                for i in range(len(word)):
                    if word[i] in self.guessed_letters:
                        flag = 1
                if flag == 1:
                    continue
                else:
                    newndup.append(word)
            self.ndupdict = newndup
            self.full_dictionary_common_letter_sorted = collections.Counter(
                "".join(self.ndupdict)
            ).most_common()
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter, instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break
                    
                    
        if guess_letter in self.guessed_letters:
            # print("already guessed")
            # self.current_dictionary = self.full_dictionary
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter, instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break
        self.start = 0
        return guess_letter

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################

    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location, "r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary

    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
        self.start = 1
        self.ndupdict = []
        for word in self.full_dictionary:
            temp = ""
            for i in range(len(word)):
                if word[i] not in temp:
                    temp += word[i]
            self.ndupdict.append(temp)
        self.full_dictionary_common_letter_sorted = collections.Counter(
            "".join(self.ndupdict)
        ).most_common()

        response = self.request("/new_game", {"practice": practice})
        if response.get("status") == "approved":
            game_id = response.get("game_id")
            word = response.get("word")
            tries_remains = response.get("tries_remains")
            if verbose:
                print(
                    "Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(
                        game_id, tries_remains, word
                    )
                )
            while tries_remains > 0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                # print(len(self.current_dictionary))

                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))

                try:
                    res = self.request(
                        "/guess_letter",
                        {
                            "request": "guess_letter",
                            "game_id": game_id,
                            "letter": guess_letter,
                        },
                    )
                except HangmanAPIError:
                    print("HangmanAPIError exception caught on request.")
                    continue
                except Exception as e:
                    print("Other exception caught on request.")
                    raise e

                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get("status")
                tries_remains = res.get("tries_remains")
                if status == "success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status == "failed":
                    reason = res.get("reason", "# of tries exceeded!")
                    if verbose:
                        print(
                            "Failed game: {0}. Because of: {1}".format(game_id, reason)
                        )
                    return False
                elif status == "ongoing":
                    word = res.get("word")
        else:
            if verbose:
                print("Failed to start a new game")
        return status == "success"

    def my_status(self):
        return self.request("/my_status", {})

    def request(self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False,
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if "json" in headers["content-type"]:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError("Maintype was not text, or querystring")

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result


class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="e378eb211fd80ea8ca07ba2fd52d79", timeout=2000)

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
api.start_game(practice=1,verbose=False)
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
practice_success_rate = total_practice_successes / total_practice_runs
print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
print(total_practice_successes)
# Out:
# run 2268 practice games out of an allotted 100,000. practice success rate so far = 0.377
# 854

# %%
for i in range (0) :
    print(i)
    api.start_game(practice=1, verbose=False)
    [
        total_practice_runs,
        total_recorded_runs,
        total_recorded_successes,
        total_practice_successes,
    ] = api.my_status()  # Get my game stats: (# of tries, # of wins)
    print("total wins %d" % (total_practice_successes))
    time.sleep(1)

practice_success_rate = total_practice_successes / total_practice_runs
print(
    "run %d practice games out of an allotted 100,000. practice success rate so far = %.3f"
    % (total_practice_runs, practice_success_rate)
)
# Out:
# run 2334 practice games out of an allotted 100,000. practice success rate so far = 0.385

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    api.start_game(practice=0,verbose=False)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    success_rate = total_recorded_successes/total_recorded_runs
    print('overall success rate = %.3f' % success_rate)
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# overall success rate = 0.417
# Playing  1  th game
# overall success rate = 0.462
# Playing  2  th game
# overall success rate = 0.500
# Playing  3  th game
# overall success rate = 0.533
# Playing  4  th game
# overall success rate = 0.500
# Playing  5  th game
# overall success rate = 0.471
# Playing  6  th game
# overall success rate = 0.500
# Playing  7  th game
# overall success rate = 0.526
# Playing  8  th game
# overall success rate = 0.550
# Playing  9  th game
# overall success rate = 0.524
# Playing  10  th game
# overall success rate = 0.500
# Playing  11  th game
# overall success rate = 0.522
# Playing  12  th game
# overall success rate = 0.500
# Playing  13  th game
# overall success rate = 0.480
# Playing  14  th game
# overall success rate = 0.462
# Playing  15  th game
# overall success rate = 0.444
# Playing  16  th game
# overall success rate = 0.464
# Playing  17  th game
# overall success rate = 0.483
# Playing  18  th game
# overall success rate = 0.467
# Playing  19  th game
# overall success rate = 0.452
# Playing  20  th game
# overall success rate = 0.438
# Playing  21  th game
# overall success rate = 0.455
# Playing  22  th game
# overall success rate = 0.441
# Playing  23  th game
# overall success rate = 0.429
# Playing  24  th game
# overall success rate = 0.444
# Playing  25  th game
# overall success rate = 0.459
# Playing  26  th game
# overall success rate = 0.474
# Playing  27  th game
# overall success rate = 0.462
# Playing  28  th game
# overall success rate = 0.475
# Playing  29  th game
# overall success rate = 0.488
# Playing  30  th game
# overall success rate = 0.500
# Playing  31  th game
# overall success rate = 0.512
# Playing  32  th game
# overall success rate = 0.523
# Playing  33  th game
# overall success rate = 0.511
# Playing  34  th game
# overall success rate = 0.522
# Playing  35  th game
# overall success rate = 0.511
# Playing  36  th game
# overall success rate = 0.521
# Playing  37  th game
# overall success rate = 0.510
# Playing  38  th game
# overall success rate = 0.500
# Playing  39  th game
# overall success rate = 0.490
# Playing  40  th game
# overall success rate = 0.481
# Playing  41  th game
# overall success rate = 0.491
# Playing  42  th game
# overall success rate = 0.481
# Playing  43  th game
# overall success rate = 0.473
# Playing  44  th game
# overall success rate = 0.482
# Playing  45  th game
# overall success rate = 0.491
# Playing  46  th game
# overall success rate = 0.483
# Playing  47  th game
# overall success rate = 0.492
# Playing  48  th game
# overall success rate = 0.500
# Playing  49  th game
# overall success rate = 0.508
# Playing  50  th game
# overall success rate = 0.516
# Playing  51  th game
# overall success rate = 0.524
# Playing  52  th game
# overall success rate = 0.531
# Playing  53  th game
# overall success rate = 0.538
# Playing  54  th game
# overall success rate = 0.530
# Playing  55  th game
# overall success rate = 0.537
# Playing  56  th game
# overall success rate = 0.544
# Playing  57  th game
# overall success rate = 0.551
# Playing  58  th game
# overall success rate = 0.557
# Playing  59  th game
# overall success rate = 0.549
# Playing  60  th game
# overall success rate = 0.556
# Playing  61  th game
# overall success rate = 0.548
# Playing  62  th game
# overall success rate = 0.541
# Playing  63  th game
# overall success rate = 0.547
# Playing  64  th game
# overall success rate = 0.553
# Playing  65  th game
# overall success rate = 0.545
# Playing  66  th game
# overall success rate = 0.551
# Playing  67  th game
# overall success rate = 0.544
# Playing  68  th game
# overall success rate = 0.537
# Playing  69  th game
# overall success rate = 0.531
# Playing  70  th game
# overall success rate = 0.524
# Playing  71  th game
# overall success rate = 0.518
# Playing  72  th game
# overall success rate = 0.524
# Playing  73  th game
# overall success rate = 0.529
# Playing  74  th game
# overall success rate = 0.523
# Playing  75  th game
# overall success rate = 0.529
# Playing  76  th game
# overall success rate = 0.523
# Playing  77  th game
# overall success rate = 0.528
# Playing  78  th game
# overall success rate = 0.533
# Playing  79  th game
# overall success rate = 0.527
# Playing  80  th game
# overall success rate = 0.533
# Playing  81  th game
# overall success rate = 0.538
# Playing  82  th game
# overall success rate = 0.532
# Playing  83  th game
# overall success rate = 0.526
# Playing  84  th game
# overall success rate = 0.531
# Playing  85  th game
# overall success rate = 0.526
# Playing  86  th game
# overall success rate = 0.531
# Playing  87  th game
# overall success rate = 0.525
# Playing  88  th game
# overall success rate = 0.530
# Playing  89  th game
# overall success rate = 0.535
# Playing  90  th game
# overall success rate = 0.539
# Playing  91  th game
# overall success rate = 0.544
# Playing  92  th game
# overall success rate = 0.548
# Playing  93  th game
# overall success rate = 0.552
# Playing  94  th game
# overall success rate = 0.547
# Playing  95  th game
# overall success rate = 0.542
# Playing  96  th game
# overall success rate = 0.537
# Playing  97  th game
# overall success rate = 0.541
# Playing  98  th game
# overall success rate = 0.545
# Playing  99  th game
# overall success rate = 0.550
# Playing  100  th game
# overall success rate = 0.545
# Playing  101  th game
# overall success rate = 0.549
# Playing  102  th game
# overall success rate = 0.553
# Playing  103  th game
# overall success rate = 0.548
# Playing  104  th game
# overall success rate = 0.552
# Playing  105  th game
# overall success rate = 0.556
# Playing  106  th game
# overall success rate = 0.559
# Playing  107  th game
# overall success rate = 0.555
# Playing  108  th game
# overall success rate = 0.558
# Playing  109  th game
# overall success rate = 0.562
# Playing  110  th game
# overall success rate = 0.566
# Playing  111  th game
# overall success rate = 0.569
# Playing  112  th game
# overall success rate = 0.573
# Playing  113  th game
# overall success rate = 0.568
# Playing  114  th game
# overall success rate = 0.571
# Playing  115  th game
# overall success rate = 0.575
# Playing  116  th game
# overall success rate = 0.578
# Playing  117  th game
# overall success rate = 0.581
# Playing  118  th game
# overall success rate = 0.585
# Playing  119  th game
# overall success rate = 0.580
# Playing  120  th game
# overall success rate = 0.583
# Playing  121  th game
# overall success rate = 0.586
# Playing  122  th game
# overall success rate = 0.590
# Playing  123  th game
# overall success rate = 0.585
# Playing  124  th game
# overall success rate = 0.581
# Playing  125  th game
# overall success rate = 0.584
# Playing  126  th game
# overall success rate = 0.587
# Playing  127  th game
# overall success rate = 0.583
# Playing  128  th game
# overall success rate = 0.586
# Playing  129  th game
# overall success rate = 0.589
# Playing  130  th game
# overall success rate = 0.592
# Playing  131  th game
# overall success rate = 0.594
# Playing  132  th game
# overall success rate = 0.590
# Playing  133  th game
# overall success rate = 0.593
# Playing  134  th game
# overall success rate = 0.596
# Playing  135  th game
# overall success rate = 0.592
# Playing  136  th game
# overall success rate = 0.588
# Playing  137  th game
# overall success rate = 0.584
# Playing  138  th game
# overall success rate = 0.587
# Playing  139  th game
# overall success rate = 0.589
# Playing  140  th game
# overall success rate = 0.592
# Playing  141  th game
# overall success rate = 0.588
# Playing  142  th game
# overall success rate = 0.591
# Playing  143  th game
# overall success rate = 0.594
# Playing  144  th game
# overall success rate = 0.596
# Playing  145  th game
# overall success rate = 0.599
# Playing  146  th game
# overall success rate = 0.601
# Playing  147  th game
# overall success rate = 0.597
# Playing  148  th game
# overall success rate = 0.600
# Playing  149  th game
# overall success rate = 0.596
# Playing  150  th game
# overall success rate = 0.593
# Playing  151  th game
# overall success rate = 0.589
# Playing  152  th game
# overall success rate = 0.591
# Playing  153  th game
# overall success rate = 0.588
# Playing  154  th game
# overall success rate = 0.584
# Playing  155  th game
# overall success rate = 0.587
# Playing  156  th game
# overall success rate = 0.589
# Playing  157  th game
# overall success rate = 0.592
# Playing  158  th game
# overall success rate = 0.588
# Playing  159  th game
# overall success rate = 0.585
# Playing  160  th game
# overall success rate = 0.587
# Playing  161  th game
# overall success rate = 0.590
# Playing  162  th game
# overall success rate = 0.592
# Playing  163  th game
# overall success rate = 0.594
# Playing  164  th game
# overall success rate = 0.597
# Playing  165  th game
# overall success rate = 0.599
# Playing  166  th game
# overall success rate = 0.596
# Playing  167  th game
# overall success rate = 0.598
# Playing  168  th game
# overall success rate = 0.594
# Playing  169  th game
# overall success rate = 0.597
# Playing  170  th game
# overall success rate = 0.593
# Playing  171  th game
# overall success rate = 0.596
# Playing  172  th game
# overall success rate = 0.592
# Playing  173  th game
# overall success rate = 0.595
# Playing  174  th game
# overall success rate = 0.597
# Playing  175  th game
# overall success rate = 0.599
# Playing  176  th game
# overall success rate = 0.596
# Playing  177  th game
# overall success rate = 0.598
# Playing  178  th game
# overall success rate = 0.600
# Playing  179  th game
# overall success rate = 0.602
# Playing  180  th game
# overall success rate = 0.604
# Playing  181  th game
# overall success rate = 0.601
# Playing  182  th game
# overall success rate = 0.603
# Playing  183  th game
# overall success rate = 0.605
# Playing  184  th game
# overall success rate = 0.607
# Playing  185  th game
# overall success rate = 0.609
# Playing  186  th game
# overall success rate = 0.611
# Playing  187  th game
# overall success rate = 0.613
# Playing  188  th game
# overall success rate = 0.610
# Playing  189  th game
# overall success rate = 0.612
# Playing  190  th game
# overall success rate = 0.609
# Playing  191  th game
# overall success rate = 0.611
# Playing  192  th game
# overall success rate = 0.613
# Playing  193  th game
# overall success rate = 0.615
# Playing  194  th game
# overall success rate = 0.612
# Playing  195  th game
# overall success rate = 0.609
# Playing  196  th game
# overall success rate = 0.611
# Playing  197  th game
# overall success rate = 0.612
# Playing  198  th game
# overall success rate = 0.614
# Playing  199  th game
# overall success rate = 0.616
# Playing  200  th game
# overall success rate = 0.618
# Playing  201  th game
# overall success rate = 0.615
# Playing  202  th game
# overall success rate = 0.617
# Playing  203  th game
# overall success rate = 0.619
# Playing  204  th game
# overall success rate = 0.616
# Playing  205  th game
# overall success rate = 0.613
# Playing  206  th game
# overall success rate = 0.610
# Playing  207  th game
# overall success rate = 0.612
# Playing  208  th game
# overall success rate = 0.614
# Playing  209  th game
# overall success rate = 0.611
# Playing  210  th game
# overall success rate = 0.608
# Playing  211  th game
# overall success rate = 0.605
# Playing  212  th game
# overall success rate = 0.603
# Playing  213  th game
# overall success rate = 0.604
# Playing  214  th game
# overall success rate = 0.606
# Playing  215  th game
# overall success rate = 0.604
# Playing  216  th game
# overall success rate = 0.605
# Playing  217  th game
# overall success rate = 0.607
# Playing  218  th game
# overall success rate = 0.609
# Playing  219  th game
# overall success rate = 0.606
# Playing  220  th game
# overall success rate = 0.608
# Playing  221  th game
# overall success rate = 0.609
# Playing  222  th game
# overall success rate = 0.611
# Playing  223  th game
# overall success rate = 0.613
# Playing  224  th game
# overall success rate = 0.610
# Playing  225  th game
# overall success rate = 0.608
# Playing  226  th game
# overall success rate = 0.605
# Playing  227  th game
# overall success rate = 0.607
# Playing  228  th game
# overall success rate = 0.608
# Playing  229  th game
# overall success rate = 0.610
# Playing  230  th game
# overall success rate = 0.612
# Playing  231  th game
# overall success rate = 0.613
# Playing  232  th game
# overall success rate = 0.615
# Playing  233  th game
# overall success rate = 0.612
# Playing  234  th game
# overall success rate = 0.614
# Playing  235  th game
# overall success rate = 0.611
# Playing  236  th game
# overall success rate = 0.613
# Playing  237  th game
# overall success rate = 0.610
# Playing  238  th game
# overall success rate = 0.608
# Playing  239  th game
# overall success rate = 0.606
# Playing  240  th game
# overall success rate = 0.603
# Playing  241  th game
# overall success rate = 0.605
# Playing  242  th game
# overall success rate = 0.606
# Playing  243  th game
# overall success rate = 0.608
# Playing  244  th game
# overall success rate = 0.609
# Playing  245  th game
# overall success rate = 0.607
# Playing  246  th game
# overall success rate = 0.605
# Playing  247  th game
# overall success rate = 0.602
# Playing  248  th game
# overall success rate = 0.604
# Playing  249  th game
# overall success rate = 0.605
# Playing  250  th game
# overall success rate = 0.607
# Playing  251  th game
# overall success rate = 0.605
# Playing  252  th game
# overall success rate = 0.606
# Playing  253  th game
# overall success rate = 0.604
# Playing  254  th game
# overall success rate = 0.605
# Playing  255  th game
# overall success rate = 0.603
# Playing  256  th game
# overall success rate = 0.604
# Playing  257  th game
# overall success rate = 0.606
# Playing  258  th game
# overall success rate = 0.607
# Playing  259  th game
# overall success rate = 0.609
# Playing  260  th game
# overall success rate = 0.610
# Playing  261  th game
# overall success rate = 0.612
# Playing  262  th game
# overall success rate = 0.609
# Playing  263  th game
# overall success rate = 0.607
# Playing  264  th game
# overall success rate = 0.605
# Playing  265  th game
# overall success rate = 0.606
# Playing  266  th game
# overall success rate = 0.604
# Playing  267  th game
# overall success rate = 0.606
# Playing  268  th game
# overall success rate = 0.607
# Playing  269  th game
# overall success rate = 0.609
# Playing  270  th game
# overall success rate = 0.606
# Playing  271  th game
# overall success rate = 0.604
# Playing  272  th game
# overall success rate = 0.606
# Playing  273  th game
# overall success rate = 0.604
# Playing  274  th game
# overall success rate = 0.605
# Playing  275  th game
# overall success rate = 0.603
# Playing  276  th game
# overall success rate = 0.604
# Playing  277  th game
# overall success rate = 0.602
# Playing  278  th game
# overall success rate = 0.603
# Playing  279  th game
# overall success rate = 0.605
# Playing  280  th game
# overall success rate = 0.606
# Playing  281  th game
# overall success rate = 0.608
# Playing  282  th game
# overall success rate = 0.605
# Playing  283  th game
# overall success rate = 0.607
# Playing  284  th game
# overall success rate = 0.608
# Playing  285  th game
# overall success rate = 0.609
# Playing  286  th game
# overall success rate = 0.607
# Playing  287  th game
# overall success rate = 0.609
# Playing  288  th game
# overall success rate = 0.610
# Playing  289  th game
# overall success rate = 0.611
# Playing  290  th game
# overall success rate = 0.613
# Playing  291  th game
# overall success rate = 0.611
# Playing  292  th game
# overall success rate = 0.609
# Playing  293  th game
# overall success rate = 0.607
# Playing  294  th game
# overall success rate = 0.608
# Playing  295  th game
# overall success rate = 0.606
# Playing  296  th game
# overall success rate = 0.607
# Playing  297  th game
# overall success rate = 0.608
# Playing  298  th game
# overall success rate = 0.610
# Playing  299  th game
# overall success rate = 0.608
# Playing  300  th game
# overall success rate = 0.609
# Playing  301  th game
# overall success rate = 0.610
# Playing  302  th game
# overall success rate = 0.608
# Playing  303  th game
# overall success rate = 0.606
# Playing  304  th game
# overall success rate = 0.608
# Playing  305  th game
# overall success rate = 0.606
# Playing  306  th game
# overall success rate = 0.604
# Playing  307  th game
# overall success rate = 0.605
# Playing  308  th game
# overall success rate = 0.603
# Playing  309  th game
# overall success rate = 0.604
# Playing  310  th game
# overall success rate = 0.602
# Playing  311  th game
# overall success rate = 0.604
# Playing  312  th game
# overall success rate = 0.605
# Playing  313  th game
# overall success rate = 0.606
# Playing  314  th game
# overall success rate = 0.607
# Playing  315  th game
# overall success rate = 0.606
# Playing  316  th game
# overall success rate = 0.604
# Playing  317  th game
# overall success rate = 0.602
# Playing  318  th game
# overall success rate = 0.603
# Playing  319  th game
# overall success rate = 0.604
# Playing  320  th game
# overall success rate = 0.605
# Playing  321  th game
# overall success rate = 0.604
# Playing  322  th game
# overall success rate = 0.602
# Playing  323  th game
# overall success rate = 0.603
# Playing  324  th game
# overall success rate = 0.604
# Playing  325  th game
# overall success rate = 0.605
# Playing  326  th game
# overall success rate = 0.607
# Playing  327  th game
# overall success rate = 0.605
# Playing  328  th game
# overall success rate = 0.606
# Playing  329  th game
# overall success rate = 0.607
# Playing  330  th game
# overall success rate = 0.605
# Playing  331  th game
# overall success rate = 0.606
# Playing  332  th game
# overall success rate = 0.608
# Playing  333  th game
# overall success rate = 0.609
# Playing  334  th game
# overall success rate = 0.610
# Playing  335  th game
# overall success rate = 0.608
# Playing  336  th game
# overall success rate = 0.609
# Playing  337  th game
# overall success rate = 0.610
# Playing  338  th game
# overall success rate = 0.611
# Playing  339  th game
# overall success rate = 0.610
# Playing  340  th game
# overall success rate = 0.608
# Playing  341  th game
# overall success rate = 0.609
# Playing  342  th game
# overall success rate = 0.610
# Playing  343  th game
# overall success rate = 0.611
# Playing  344  th game
# overall success rate = 0.610
# Playing  345  th game
# overall success rate = 0.611
# Playing  346  th game
# overall success rate = 0.612
# Playing  347  th game
# overall success rate = 0.610
# Playing  348  th game
# overall success rate = 0.608
# Playing  349  th game
# overall success rate = 0.609
# Playing  350  th game
# overall success rate = 0.610
# Playing  351  th game
# overall success rate = 0.612
# Playing  352  th game
# overall success rate = 0.610
# Playing  353  th game
# overall success rate = 0.611
# Playing  354  th game
# overall success rate = 0.612
# Playing  355  th game
# overall success rate = 0.610
# Playing  356  th game
# overall success rate = 0.611
# Playing  357  th game
# overall success rate = 0.610
# Playing  358  th game
# overall success rate = 0.611
# Playing  359  th game
# overall success rate = 0.612
# Playing  360  th game
# overall success rate = 0.613
# Playing  361  th game
# overall success rate = 0.614
# Playing  362  th game
# overall success rate = 0.612
# Playing  363  th game
# overall success rate = 0.613
# Playing  364  th game
# overall success rate = 0.612
# Playing  365  th game
# overall success rate = 0.613
# Playing  366  th game
# overall success rate = 0.611
# Playing  367  th game
# overall success rate = 0.609
# Playing  368  th game
# overall success rate = 0.611
# Playing  369  th game
# overall success rate = 0.609
# Playing  370  th game
# overall success rate = 0.607
# Playing  371  th game
# overall success rate = 0.608
# Playing  372  th game
# overall success rate = 0.609
# Playing  373  th game
# overall success rate = 0.608
# Playing  374  th game
# overall success rate = 0.609
# Playing  375  th game
# overall success rate = 0.610
# Playing  376  th game
# overall success rate = 0.608
# Playing  377  th game
# overall success rate = 0.607
# Playing  378  th game
# overall success rate = 0.608
# Playing  379  th game
# overall success rate = 0.606
# Playing  380  th game
# overall success rate = 0.607
# Playing  381  th game
# overall success rate = 0.608
# Playing  382  th game
# overall success rate = 0.609
# Playing  383  th game
# overall success rate = 0.608
# Playing  384  th game
# overall success rate = 0.606
# Playing  385  th game
# overall success rate = 0.605
# Playing  386  th game
# overall success rate = 0.606
# Playing  387  th game
# overall success rate = 0.607
# Playing  388  th game
# overall success rate = 0.605
# Playing  389  th game
# overall success rate = 0.606
# Playing  390  th game
# overall success rate = 0.604
# Playing  391  th game
# overall success rate = 0.603
# Playing  392  th game
# overall success rate = 0.601
# Playing  393  th game
# overall success rate = 0.602
# Playing  394  th game
# overall success rate = 0.603
# Playing  395  th game
# overall success rate = 0.602
# Playing  396  th game
# overall success rate = 0.600
# Playing  397  th game
# overall success rate = 0.601
# Playing  398  th game
# overall success rate = 0.600
# Playing  399  th game
# overall success rate = 0.599
# Playing  400  th game
# overall success rate = 0.600
# Playing  401  th game
# overall success rate = 0.600
# Playing  402  th game
# overall success rate = 0.599
# Playing  403  th game
# overall success rate = 0.598
# Playing  404  th game
# overall success rate = 0.599
# Playing  405  th game
# overall success rate = 0.600
# Playing  406  th game
# overall success rate = 0.598
# Playing  407  th game
# overall success rate = 0.599
# Playing  408  th game
# overall success rate = 0.598
# Playing  409  th game
# overall success rate = 0.596
# Playing  410  th game
# overall success rate = 0.597
# Playing  411  th game
# overall success rate = 0.598
# Playing  412  th game
# overall success rate = 0.599
# Playing  413  th game
# overall success rate = 0.598
# Playing  414  th game
# overall success rate = 0.599
# Playing  415  th game
# overall success rate = 0.597
# Playing  416  th game
# overall success rate = 0.598
# Playing  417  th game
# overall success rate = 0.599
# Playing  418  th game
# overall success rate = 0.600
# Playing  419  th game
# overall success rate = 0.599
# Playing  420  th game
# overall success rate = 0.600
# Playing  421  th game
# overall success rate = 0.600
# Playing  422  th game
# overall success rate = 0.599
# Playing  423  th game
# overall success rate = 0.598
# Playing  424  th game
# overall success rate = 0.599
# Playing  425  th game
# overall success rate = 0.600
# Playing  426  th game
# overall success rate = 0.600
# Playing  427  th game
# overall success rate = 0.601
# Playing  428  th game
# overall success rate = 0.602
# Playing  429  th game
# overall success rate = 0.603
# Playing  430  th game
# overall success rate = 0.604
# Playing  431  th game
# overall success rate = 0.603
# Playing  432  th game
# overall success rate = 0.604
# Playing  433  th game
# overall success rate = 0.604
# Playing  434  th game
# overall success rate = 0.605
# Playing  435  th game
# overall success rate = 0.606
# Playing  436  th game
# overall success rate = 0.605
# Playing  437  th game
# overall success rate = 0.606
# Playing  438  th game
# overall success rate = 0.604
# Playing  439  th game
# overall success rate = 0.603
# Playing  440  th game
# overall success rate = 0.604
# Playing  441  th game
# overall success rate = 0.605
# Playing  442  th game
# overall success rate = 0.606
# Playing  443  th game
# overall success rate = 0.604
# Playing  444  th game
# overall success rate = 0.605
# Playing  445  th game
# overall success rate = 0.604
# Playing  446  th game
# overall success rate = 0.605
# Playing  447  th game
# overall success rate = 0.603
# Playing  448  th game
# overall success rate = 0.602
# Playing  449  th game
# overall success rate = 0.601
# Playing  450  th game
# overall success rate = 0.600
# Playing  451  th game
# overall success rate = 0.598
# Playing  452  th game
# overall success rate = 0.599
# Playing  453  th game
# overall success rate = 0.600
# Playing  454  th game
# overall success rate = 0.601
# Playing  455  th game
# overall success rate = 0.602
# Playing  456  th game
# overall success rate = 0.603
# Playing  457  th game
# overall success rate = 0.603
# Playing  458  th game
# overall success rate = 0.604
# Playing  459  th game
# overall success rate = 0.603
# Playing  460  th game
# overall success rate = 0.602
# Playing  461  th game
# overall success rate = 0.600
# Playing  462  th game
# overall success rate = 0.601
# Playing  463  th game
# overall success rate = 0.602
# Playing  464  th game
# overall success rate = 0.603
# Playing  465  th game
# overall success rate = 0.604
# Playing  466  th game
# overall success rate = 0.605
# Playing  467  th game
# overall success rate = 0.603
# Playing  468  th game
# overall success rate = 0.604
# Playing  469  th game
# overall success rate = 0.603
# Playing  470  th game
# overall success rate = 0.602
# Playing  471  th game
# overall success rate = 0.602
# Playing  472  th game
# overall success rate = 0.603
# Playing  473  th game
# overall success rate = 0.602
# Playing  474  th game
# overall success rate = 0.603
# Playing  475  th game
# overall success rate = 0.604
# Playing  476  th game
# overall success rate = 0.605
# Playing  477  th game
# overall success rate = 0.605
# Playing  478  th game
# overall success rate = 0.606
# Playing  479  th game
# overall success rate = 0.607
# Playing  480  th game
# overall success rate = 0.608
# Playing  481  th game
# overall success rate = 0.609
# Playing  482  th game
# overall success rate = 0.609
# Playing  483  th game
# overall success rate = 0.610
# Playing  484  th game
# overall success rate = 0.611
# Playing  485  th game
# overall success rate = 0.612
# Playing  486  th game
# overall success rate = 0.612
# Playing  487  th game
# overall success rate = 0.613
# Playing  488  th game
# overall success rate = 0.612
# Playing  489  th game
# overall success rate = 0.611
# Playing  490  th game
# overall success rate = 0.610
# Playing  491  th game
# overall success rate = 0.610
# Playing  492  th game
# overall success rate = 0.609
# Playing  493  th game
# overall success rate = 0.608
# Playing  494  th game
# overall success rate = 0.607
# Playing  495  th game
# overall success rate = 0.607
# Playing  496  th game
# overall success rate = 0.606
# Playing  497  th game
# overall success rate = 0.607
# Playing  498  th game
# overall success rate = 0.606
# Playing  499  th game
# overall success rate = 0.605
# Playing  500  th game
# overall success rate = 0.605
# Playing  501  th game
# overall success rate = 0.606
# Playing  502  th game
# overall success rate = 0.607
# Playing  503  th game
# overall success rate = 0.606
# Playing  504  th game
# overall success rate = 0.605
# Playing  505  th game
# overall success rate = 0.605
# Playing  506  th game
# overall success rate = 0.604
# Playing  507  th game
# overall success rate = 0.605
# Playing  508  th game
# overall success rate = 0.606
# Playing  509  th game
# overall success rate = 0.605
# Playing  510  th game
# overall success rate = 0.605
# Playing  511  th game
# overall success rate = 0.606
# Playing  512  th game
# overall success rate = 0.607
# Playing  513  th game
# overall success rate = 0.606
# Playing  514  th game
# overall success rate = 0.606
# Playing  515  th game
# overall success rate = 0.605
# Playing  516  th game
# overall success rate = 0.606
# Playing  517  th game
# overall success rate = 0.607
# Playing  518  th game
# overall success rate = 0.608
# Playing  519  th game
# overall success rate = 0.606
# Playing  520  th game
# overall success rate = 0.605
# Playing  521  th game
# overall success rate = 0.606
# Playing  522  th game
# overall success rate = 0.607
# Playing  523  th game
# overall success rate = 0.606
# Playing  524  th game
# overall success rate = 0.604
# Playing  525  th game
# overall success rate = 0.603
# Playing  526  th game
# overall success rate = 0.602
# Playing  527  th game
# overall success rate = 0.603
# Playing  528  th game
# overall success rate = 0.604
# Playing  529  th game
# overall success rate = 0.603
# Playing  530  th game
# overall success rate = 0.603
# Playing  531  th game
# overall success rate = 0.604
# Playing  532  th game
# overall success rate = 0.605
# Playing  533  th game
# overall success rate = 0.606
# Playing  534  th game
# overall success rate = 0.606
# Playing  535  th game
# overall success rate = 0.607
# Playing  536  th game
# overall success rate = 0.608
# Playing  537  th game
# overall success rate = 0.608
# Playing  538  th game
# overall success rate = 0.607
# Playing  539  th game
# overall success rate = 0.606
# Playing  540  th game
# overall success rate = 0.607
# Playing  541  th game
# overall success rate = 0.606
# Playing  542  th game
# overall success rate = 0.606
# Playing  543  th game
# overall success rate = 0.605
# Playing  544  th game
# overall success rate = 0.606
# Playing  545  th game
# overall success rate = 0.607
# Playing  546  th game
# overall success rate = 0.608
# Playing  547  th game
# overall success rate = 0.606
# Playing  548  th game
# overall success rate = 0.607
# Playing  549  th game
# overall success rate = 0.608
# Playing  550  th game
# overall success rate = 0.609
# Playing  551  th game
# overall success rate = 0.607
# Playing  552  th game
# overall success rate = 0.606
# Playing  553  th game
# overall success rate = 0.605
# Playing  554  th game
# overall success rate = 0.606
# Playing  555  th game
# overall success rate = 0.605
# Playing  556  th game
# overall success rate = 0.604
# Playing  557  th game
# overall success rate = 0.603
# Playing  558  th game
# overall success rate = 0.602
# Playing  559  th game
# overall success rate = 0.602
# Playing  560  th game
# overall success rate = 0.603
# Playing  561  th game
# overall success rate = 0.604
# Playing  562  th game
# overall success rate = 0.603
# Playing  563  th game
# overall success rate = 0.602
# Playing  564  th game
# overall success rate = 0.601
# Playing  565  th game
# overall success rate = 0.600
# Playing  566  th game
# overall success rate = 0.600
# Playing  567  th game
# overall success rate = 0.601
# Playing  568  th game
# overall success rate = 0.602
# Playing  569  th game
# overall success rate = 0.602
# Playing  570  th game
# overall success rate = 0.603
# Playing  571  th game
# overall success rate = 0.604
# Playing  572  th game
# overall success rate = 0.604
# Playing  573  th game
# overall success rate = 0.605
# Playing  574  th game
# overall success rate = 0.606
# Playing  575  th game
# overall success rate = 0.606
# Playing  576  th game
# overall success rate = 0.607
# Playing  577  th game
# overall success rate = 0.608
# Playing  578  th game
# overall success rate = 0.608
# Playing  579  th game
# overall success rate = 0.607
# Playing  580  th game
# overall success rate = 0.606
# Playing  581  th game
# overall success rate = 0.605
# Playing  582  th game
# overall success rate = 0.604
# Playing  583  th game
# overall success rate = 0.603
# Playing  584  th game
# overall success rate = 0.604
# Playing  585  th game
# overall success rate = 0.605
# Playing  586  th game
# overall success rate = 0.605
# Playing  587  th game
# overall success rate = 0.606
# Playing  588  th game
# overall success rate = 0.607
# Playing  589  th game
# overall success rate = 0.606
# Playing  590  th game
# overall success rate = 0.605
# Playing  591  th game
# overall success rate = 0.605
# Playing  592  th game
# overall success rate = 0.606
# Playing  593  th game
# overall success rate = 0.605
# Playing  594  th game
# overall success rate = 0.606
# Playing  595  th game
# overall success rate = 0.605
# Playing  596  th game
# overall success rate = 0.604
# Playing  597  th game
# overall success rate = 0.603
# Playing  598  th game
# overall success rate = 0.602
# Playing  599  th game
# overall success rate = 0.602
# Playing  600  th game
# overall success rate = 0.601
# Playing  601  th game
# overall success rate = 0.600
# Playing  602  th game
# overall success rate = 0.601
# Playing  603  th game
# overall success rate = 0.602
# Playing  604  th game
# overall success rate = 0.602
# Playing  605  th game
# overall success rate = 0.603
# Playing  606  th game
# overall success rate = 0.602
# Playing  607  th game
# overall success rate = 0.601
# Playing  608  th game
# overall success rate = 0.600
# Playing  609  th game
# overall success rate = 0.601
# Playing  610  th game
# overall success rate = 0.601
# Playing  611  th game
# overall success rate = 0.602
# Playing  612  th game
# overall success rate = 0.601
# Playing  613  th game
# overall success rate = 0.600
# Playing  614  th game
# overall success rate = 0.601
# Playing  615  th game
# overall success rate = 0.601
# Playing  616  th game
# overall success rate = 0.602
# Playing  617  th game
# overall success rate = 0.603
# Playing  618  th game
# overall success rate = 0.602
# Playing  619  th game
# overall success rate = 0.602
# Playing  620  th game
# overall success rate = 0.601
# Playing  621  th game
# overall success rate = 0.600
# Playing  622  th game
# overall success rate = 0.599
# Playing  623  th game
# overall success rate = 0.598
# Playing  624  th game
# overall success rate = 0.599
# Playing  625  th game
# overall success rate = 0.600
# Playing  626  th game
# overall success rate = 0.600
# Playing  627  th game
# overall success rate = 0.601
# Playing  628  th game
# overall success rate = 0.602
# Playing  629  th game
# overall success rate = 0.602
# Playing  630  th game
# overall success rate = 0.603
# Playing  631  th game
# overall success rate = 0.603
# Playing  632  th game
# overall success rate = 0.602
# Playing  633  th game
# overall success rate = 0.603
# Playing  634  th game
# overall success rate = 0.604
# Playing  635  th game
# overall success rate = 0.603
# Playing  636  th game
# overall success rate = 0.603
# Playing  637  th game
# overall success rate = 0.602
# Playing  638  th game
# overall success rate = 0.603
# Playing  639  th game
# overall success rate = 0.602
# Playing  640  th game
# overall success rate = 0.601
# Playing  641  th game
# overall success rate = 0.600
# Playing  642  th game
# overall success rate = 0.601
# Playing  643  th game
# overall success rate = 0.602
# Playing  644  th game
# overall success rate = 0.602
# Playing  645  th game
# overall success rate = 0.601
# Playing  646  th game
# overall success rate = 0.600
# Playing  647  th game
# overall success rate = 0.601
# Playing  648  th game
# overall success rate = 0.602
# Playing  649  th game
# overall success rate = 0.602
# Playing  650  th game
# overall success rate = 0.603
# Playing  651  th game
# overall success rate = 0.603
# Playing  652  th game
# overall success rate = 0.604
# Playing  653  th game
# overall success rate = 0.603
# Playing  654  th game
# overall success rate = 0.604
# Playing  655  th game
# overall success rate = 0.603
# Playing  656  th game
# overall success rate = 0.603
# Playing  657  th game
# overall success rate = 0.604
# Playing  658  th game
# overall success rate = 0.603
# Playing  659  th game
# overall success rate = 0.602
# Playing  660  th game
# overall success rate = 0.603
# Playing  661  th game
# overall success rate = 0.603
# Playing  662  th game
# overall success rate = 0.604
# Playing  663  th game
# overall success rate = 0.603
# Playing  664  th game
# overall success rate = 0.604
# Playing  665  th game
# overall success rate = 0.603
# Playing  666  th game
# overall success rate = 0.603
# Playing  667  th game
# overall success rate = 0.604
# Playing  668  th game
# overall success rate = 0.603
# Playing  669  th game
# overall success rate = 0.604
# Playing  670  th game
# overall success rate = 0.603
# Playing  671  th game
# overall success rate = 0.603
# Playing  672  th game
# overall success rate = 0.604
# Playing  673  th game
# overall success rate = 0.603
# Playing  674  th game
# overall success rate = 0.602
# Playing  675  th game
# overall success rate = 0.603
# Playing  676  th game
# overall success rate = 0.602
# Playing  677  th game
# overall success rate = 0.602
# Playing  678  th game
# overall success rate = 0.603
# Playing  679  th game
# overall success rate = 0.603
# Playing  680  th game
# overall success rate = 0.604
# Playing  681  th game
# overall success rate = 0.605
# Playing  682  th game
# overall success rate = 0.604
# Playing  683  th game
# overall success rate = 0.603
# Playing  684  th game
# overall success rate = 0.602
# Playing  685  th game
# overall success rate = 0.603
# Playing  686  th game
# overall success rate = 0.603
# Playing  687  th game
# overall success rate = 0.604
# Playing  688  th game
# overall success rate = 0.603
# Playing  689  th game
# overall success rate = 0.603
# Playing  690  th game
# overall success rate = 0.603
# Playing  691  th game
# overall success rate = 0.603
# Playing  692  th game
# overall success rate = 0.604
# Playing  693  th game
# overall success rate = 0.604
# Playing  694  th game
# overall success rate = 0.605
# Playing  695  th game
# overall success rate = 0.605
# Playing  696  th game
# overall success rate = 0.605
# Playing  697  th game
# overall success rate = 0.605
# Playing  698  th game
# overall success rate = 0.606
# Playing  699  th game
# overall success rate = 0.606
# Playing  700  th game
# overall success rate = 0.607
# Playing  701  th game
# overall success rate = 0.606
# Playing  702  th game
# overall success rate = 0.605
# Playing  703  th game
# overall success rate = 0.606
# Playing  704  th game
# overall success rate = 0.606
# Playing  705  th game
# overall success rate = 0.607
# Playing  706  th game
# overall success rate = 0.606
# Playing  707  th game
# overall success rate = 0.606
# Playing  708  th game
# overall success rate = 0.607
# Playing  709  th game
# overall success rate = 0.607
# Playing  710  th game
# overall success rate = 0.608
# Playing  711  th game
# overall success rate = 0.609
# Playing  712  th game
# overall success rate = 0.608
# Playing  713  th game
# overall success rate = 0.607
# Playing  714  th game
# overall success rate = 0.607
# Playing  715  th game
# overall success rate = 0.608
# Playing  716  th game
# overall success rate = 0.607
# Playing  717  th game
# overall success rate = 0.608
# Playing  718  th game
# overall success rate = 0.608
# Playing  719  th game
# overall success rate = 0.609
# Playing  720  th game
# overall success rate = 0.609
# Playing  721  th game
# overall success rate = 0.610
# Playing  722  th game
# overall success rate = 0.610
# Playing  723  th game
# overall success rate = 0.610
# Playing  724  th game
# overall success rate = 0.610
# Playing  725  th game
# overall success rate = 0.609
# Playing  726  th game
# overall success rate = 0.608
# Playing  727  th game
# overall success rate = 0.609
# Playing  728  th game
# overall success rate = 0.608
# Playing  729  th game
# overall success rate = 0.609
# Playing  730  th game
# overall success rate = 0.609
# Playing  731  th game
# overall success rate = 0.610
# Playing  732  th game
# overall success rate = 0.610
# Playing  733  th game
# overall success rate = 0.609
# Playing  734  th game
# overall success rate = 0.609
# Playing  735  th game
# overall success rate = 0.609
# Playing  736  th game
# overall success rate = 0.608
# Playing  737  th game
# overall success rate = 0.609
# Playing  738  th game
# overall success rate = 0.609
# Playing  739  th game
# overall success rate = 0.610
# Playing  740  th game
# overall success rate = 0.610
# Playing  741  th game
# overall success rate = 0.610
# Playing  742  th game
# overall success rate = 0.609
# Playing  743  th game
# overall success rate = 0.608
# Playing  744  th game
# overall success rate = 0.607
# Playing  745  th game
# overall success rate = 0.608
# Playing  746  th game
# overall success rate = 0.607
# Playing  747  th game
# overall success rate = 0.607
# Playing  748  th game
# overall success rate = 0.607
# Playing  749  th game
# overall success rate = 0.607
# Playing  750  th game
# overall success rate = 0.608
# Playing  751  th game
# overall success rate = 0.607
# Playing  752  th game
# overall success rate = 0.607
# Playing  753  th game
# overall success rate = 0.607
# Playing  754  th game
# overall success rate = 0.607
# Playing  755  th game
# overall success rate = 0.606
# Playing  756  th game
# overall success rate = 0.607
# Playing  757  th game
# overall success rate = 0.606
# Playing  758  th game
# overall success rate = 0.606
# Playing  759  th game
# overall success rate = 0.607
# Playing  760  th game
# overall success rate = 0.608
# Playing  761  th game
# overall success rate = 0.608
# Playing  762  th game
# overall success rate = 0.609
# Playing  763  th game
# overall success rate = 0.609
# Playing  764  th game
# overall success rate = 0.608
# Playing  765  th game
# overall success rate = 0.609
# Playing  766  th game
# overall success rate = 0.608
# Playing  767  th game
# overall success rate = 0.607
# Playing  768  th game
# overall success rate = 0.606
# Playing  769  th game
# overall success rate = 0.607
# Playing  770  th game
# overall success rate = 0.606
# Playing  771  th game
# overall success rate = 0.605
# Playing  772  th game
# overall success rate = 0.606
# Playing  773  th game
# overall success rate = 0.606
# Playing  774  th game
# overall success rate = 0.607
# Playing  775  th game
# overall success rate = 0.607
# Playing  776  th game
# overall success rate = 0.607
# Playing  777  th game
# overall success rate = 0.607
# Playing  778  th game
# overall success rate = 0.608
# Playing  779  th game
# overall success rate = 0.607
# Playing  780  th game
# overall success rate = 0.607
# Playing  781  th game
# overall success rate = 0.607
# Playing  782  th game
# overall success rate = 0.607
# Playing  783  th game
# overall success rate = 0.608
# Playing  784  th game
# overall success rate = 0.608
# Playing  785  th game
# overall success rate = 0.609
# Playing  786  th game
# overall success rate = 0.609
# Playing  787  th game
# overall success rate = 0.610
# Playing  788  th game
# overall success rate = 0.610
# Playing  789  th game
# overall success rate = 0.609
# Playing  790  th game
# overall success rate = 0.608
# Playing  791  th game
# overall success rate = 0.609
# Playing  792  th game
# overall success rate = 0.608
# Playing  793  th game
# overall success rate = 0.607
# Playing  794  th game
# overall success rate = 0.608
# Playing  795  th game
# overall success rate = 0.607
# Playing  796  th game
# overall success rate = 0.608
# Playing  797  th game
# overall success rate = 0.607
# Playing  798  th game
# overall success rate = 0.606
# Playing  799  th game
# overall success rate = 0.607
# Playing  800  th game
# overall success rate = 0.606
# Playing  801  th game
# overall success rate = 0.606
# Playing  802  th game
# overall success rate = 0.606
# Playing  803  th game
# overall success rate = 0.605
# Playing  804  th game
# overall success rate = 0.605
# Playing  805  th game
# overall success rate = 0.606
# Playing  806  th game
# overall success rate = 0.606
# Playing  807  th game
# overall success rate = 0.606
# Playing  808  th game
# overall success rate = 0.606
# Playing  809  th game
# overall success rate = 0.607
# Playing  810  th game
# overall success rate = 0.607
# Playing  811  th game
# overall success rate = 0.608
# Playing  812  th game
# overall success rate = 0.607
# Playing  813  th game
# overall success rate = 0.606
# Playing  814  th game
# overall success rate = 0.607
# Playing  815  th game
# overall success rate = 0.606
# Playing  816  th game
# overall success rate = 0.605
# Playing  817  th game
# overall success rate = 0.606
# Playing  818  th game
# overall success rate = 0.605
# Playing  819  th game
# overall success rate = 0.604
# Playing  820  th game
# overall success rate = 0.605
# Playing  821  th game
# overall success rate = 0.605
# Playing  822  th game
# overall success rate = 0.606
# Playing  823  th game
# overall success rate = 0.606
# Playing  824  th game
# overall success rate = 0.606
# Playing  825  th game
# overall success rate = 0.606
# Playing  826  th game
# overall success rate = 0.605
# Playing  827  th game
# overall success rate = 0.604
# Playing  828  th game
# overall success rate = 0.605
# Playing  829  th game
# overall success rate = 0.605
# Playing  830  th game
# overall success rate = 0.605
# Playing  831  th game
# overall success rate = 0.604
# Playing  832  th game
# overall success rate = 0.604
# Playing  833  th game
# overall success rate = 0.605
# Playing  834  th game
# overall success rate = 0.604
# Playing  835  th game
# overall success rate = 0.603
# Playing  836  th game
# overall success rate = 0.604
# Playing  837  th game
# overall success rate = 0.603
# Playing  838  th game
# overall success rate = 0.602
# Playing  839  th game
# overall success rate = 0.603
# Playing  840  th game
# overall success rate = 0.602
# Playing  841  th game
# overall success rate = 0.603
# Playing  842  th game
# overall success rate = 0.603
# Playing  843  th game
# overall success rate = 0.604
# Playing  844  th game
# overall success rate = 0.604
# Playing  845  th game
# overall success rate = 0.604
# Playing  846  th game
# overall success rate = 0.605
# Playing  847  th game
# overall success rate = 0.605
# Playing  848  th game
# overall success rate = 0.606
# Playing  849  th game
# overall success rate = 0.605
# Playing  850  th game
# overall success rate = 0.606
# Playing  851  th game
# overall success rate = 0.606
# Playing  852  th game
# overall success rate = 0.606
# Playing  853  th game
# overall success rate = 0.607
# Playing  854  th game
# overall success rate = 0.607
# Playing  855  th game
# overall success rate = 0.608
# Playing  856  th game
# overall success rate = 0.608
# Playing  857  th game
# overall success rate = 0.608
# Playing  858  th game
# overall success rate = 0.607
# Playing  859  th game
# overall success rate = 0.607
# Playing  860  th game
# overall success rate = 0.608
# Playing  861  th game
# overall success rate = 0.607
# Playing  862  th game
# overall success rate = 0.608
# Playing  863  th game
# overall success rate = 0.608
# Playing  864  th game
# overall success rate = 0.607
# Playing  865  th game
# overall success rate = 0.607
# Playing  866  th game
# overall success rate = 0.606
# Playing  867  th game
# overall success rate = 0.605
# Playing  868  th game
# overall success rate = 0.605
# Playing  869  th game
# overall success rate = 0.605
# Playing  870  th game
# overall success rate = 0.605
# Playing  871  th game
# overall success rate = 0.606
# Playing  872  th game
# overall success rate = 0.605
# Playing  873  th game
# overall success rate = 0.606
# Playing  874  th game
# overall success rate = 0.606
# Playing  875  th game
# overall success rate = 0.605
# Playing  876  th game
# overall success rate = 0.605
# Playing  877  th game
# overall success rate = 0.604
# Playing  878  th game
# overall success rate = 0.604
# Playing  879  th game
# overall success rate = 0.605
# Playing  880  th game
# overall success rate = 0.604
# Playing  881  th game
# overall success rate = 0.605
# Playing  882  th game
# overall success rate = 0.604
# Playing  883  th game
# overall success rate = 0.603
# Playing  884  th game
# overall success rate = 0.603
# Playing  885  th game
# overall success rate = 0.602
# Playing  886  th game
# overall success rate = 0.602
# Playing  887  th game
# overall success rate = 0.602
# Playing  888  th game
# overall success rate = 0.602
# Playing  889  th game
# overall success rate = 0.602
# Playing  890  th game
# overall success rate = 0.601
# Playing  891  th game
# overall success rate = 0.600
# Playing  892  th game
# overall success rate = 0.600
# Playing  893  th game
# overall success rate = 0.600
# Playing  894  th game
# overall success rate = 0.600
# Playing  895  th game
# overall success rate = 0.601
# Playing  896  th game
# overall success rate = 0.601
# Playing  897  th game
# overall success rate = 0.602
# Playing  898  th game
# overall success rate = 0.602
# Playing  899  th game
# overall success rate = 0.602
# Playing  900  th game
# overall success rate = 0.601
# Playing  901  th game
# overall success rate = 0.600
# Playing  902  th game
# overall success rate = 0.600
# Playing  903  th game
# overall success rate = 0.600
# Playing  904  th game
# overall success rate = 0.599
# Playing  905  th game
# overall success rate = 0.599
# Playing  906  th game
# overall success rate = 0.599
# Playing  907  th game
# overall success rate = 0.598
# Playing  908  th game
# overall success rate = 0.599
# Playing  909  th game
# overall success rate = 0.599
# Playing  910  th game
# overall success rate = 0.600
# Playing  911  th game
# overall success rate = 0.600
# Playing  912  th game
# overall success rate = 0.601
# Playing  913  th game
# overall success rate = 0.601
# Playing  914  th game
# overall success rate = 0.602
# Playing  915  th game
# overall success rate = 0.601
# Playing  916  th game
# overall success rate = 0.601
# Playing  917  th game
# overall success rate = 0.602
# Playing  918  th game
# overall success rate = 0.602
# Playing  919  th game
# overall success rate = 0.603
# Playing  920  th game
# overall success rate = 0.603
# Playing  921  th game
# overall success rate = 0.602
# Playing  922  th game
# overall success rate = 0.603
# Playing  923  th game
# overall success rate = 0.603
# Playing  924  th game
# overall success rate = 0.603
# Playing  925  th game
# overall success rate = 0.602
# Playing  926  th game
# overall success rate = 0.602
# Playing  927  th game
# overall success rate = 0.603
# Playing  928  th game
# overall success rate = 0.603
# Playing  929  th game
# overall success rate = 0.604
# Playing  930  th game
# overall success rate = 0.604
# Playing  931  th game
# overall success rate = 0.604
# Playing  932  th game
# overall success rate = 0.605
# Playing  933  th game
# overall success rate = 0.605
# Playing  934  th game
# overall success rate = 0.605
# Playing  935  th game
# overall success rate = 0.604
# Playing  936  th game
# overall success rate = 0.604
# Playing  937  th game
# overall success rate = 0.605
# Playing  938  th game
# overall success rate = 0.604
# Playing  939  th game
# overall success rate = 0.605
# Playing  940  th game
# overall success rate = 0.605
# Playing  941  th game
# overall success rate = 0.604
# Playing  942  th game
# overall success rate = 0.605
# Playing  943  th game
# overall success rate = 0.605
# Playing  944  th game
# overall success rate = 0.606
# Playing  945  th game
# overall success rate = 0.605
# Playing  946  th game
# overall success rate = 0.605
# Playing  947  th game
# overall success rate = 0.606
# Playing  948  th game
# overall success rate = 0.606
# Playing  949  th game
# overall success rate = 0.606
# Playing  950  th game
# overall success rate = 0.606
# Playing  951  th game
# overall success rate = 0.606
# Playing  952  th game
# overall success rate = 0.607
# Playing  953  th game
# overall success rate = 0.606
# Playing  954  th game
# overall success rate = 0.607
# Playing  955  th game
# overall success rate = 0.606
# Playing  956  th game
# overall success rate = 0.605
# Playing  957  th game
# overall success rate = 0.606
# Playing  958  th game
# overall success rate = 0.606
# Playing  959  th game
# overall success rate = 0.607
# Playing  960  th game
# overall success rate = 0.607
# Playing  961  th game
# overall success rate = 0.606
# Playing  962  th game
# overall success rate = 0.606
# Playing  963  th game
# overall success rate = 0.605
# Playing  964  th game
# overall success rate = 0.606
# Playing  965  th game
# overall success rate = 0.605
# Playing  966  th game
# overall success rate = 0.605
# Playing  967  th game
# overall success rate = 0.606
# Playing  968  th game
# overall success rate = 0.606
# Playing  969  th game
# overall success rate = 0.607
# Playing  970  th game
# overall success rate = 0.606
# Playing  971  th game
# overall success rate = 0.606
# Playing  972  th game
# overall success rate = 0.606
# Playing  973  th game
# overall success rate = 0.606
# Playing  974  th game
# overall success rate = 0.606
# Playing  975  th game
# overall success rate = 0.607
# Playing  976  th game
# overall success rate = 0.607
# Playing  977  th game
# overall success rate = 0.607
# Playing  978  th game
# overall success rate = 0.606
# Playing  979  th game
# overall success rate = 0.606
# Playing  980  th game
# overall success rate = 0.607
# Playing  981  th game
# overall success rate = 0.606
# Playing  982  th game
# overall success rate = 0.607
# Playing  983  th game
# overall success rate = 0.607
# Playing  984  th game
# overall success rate = 0.606
# Playing  985  th game
# overall success rate = 0.607
# Playing  986  th game
# overall success rate = 0.607
# Playing  987  th game
# overall success rate = 0.608
# Playing  988  th game
# ---------------------------------------------------------------------------
# HangmanAPIError                           Traceback (most recent call last)
# Cell In[9], line 4
#       2 print('Playing ', i, ' th game')
#       3 # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
# ----> 4 api.start_game(practice=0,verbose=False)
#       5 [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
#       6 success_rate = total_recorded_successes/total_recorded_runs
#
# Cell In[2], line 256, in HangmanAPI.start_game(self, practice, verbose)
#     251     self.ndupdict.append(temp)
#     252 self.full_dictionary_common_letter_sorted = collections.Counter(
#     253     "".join(self.ndupdict)
#     254 ).most_common()
# --> 256 response = self.request("/new_game", {"practice": practice})
#     257 if response.get("status") == "approved":
#     258     game_id = response.get("game_id")
#
# Cell In[2], line 371, in HangmanAPI.request(self, path, args, post_args, method)
#     368     raise HangmanAPIError("Maintype was not text, or querystring")
#     370 if result and isinstance(result, dict) and result.get("error"):
# --> 371     raise HangmanAPIError(result)
#     372 return result
#
# HangmanAPIError: {'error': 'You have reached 1000 of games', 'status': 'denied'}

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)
print('total runs : %d' % total_recorded_runs)
# Out:
# overall success rate = 0.607
# total runs : 1000

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
print('total wins : %d' % total_recorded_successes)
print('total runs : %d' % total_recorded_runs)
# Out:
# total wins : 607
# total runs : 1000
